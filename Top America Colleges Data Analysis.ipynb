# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("top_america_colleges_2022.csv")
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName state  studentPopulation  \
# 0  Massachusetts Institute of Technology    MA              12195
#
#   campusSetting  medianBaseSalary  longitude   latitude             website  \
# 0         Urban          173700.0 -71.093539  42.359006  http://web.mit.edu
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#    totalStudentPop undergradPop totalGrantAid percentOfStudentsFinAid  \
# 0            12195         4582    35299332.0                    75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 25 columns]

# %%
df.shape
# Out:
# (498, 25)

# %%
df.columns
# Out:
# Index(['description', 'rank', 'organizationName', 'state', 'studentPopulation',
#        'campusSetting', 'medianBaseSalary', 'longitude', 'latitude', 'website',
#        'phoneNumber', 'city', 'country', 'state.1', 'region', 'yearFounded',
#        'stateCode', 'collegeType', 'carnegieClassification',
#        'studentFacultyRatio', 'totalStudentPop', 'undergradPop',
#        'totalGrantAid', 'percentOfStudentsFinAid', 'percentOfStudentsGrant'],
#       dtype='object')

# %%
df.dtypes
# Out:
# description                 object
# rank                         int64
# organizationName            object
# state                       object
# studentPopulation            int64
# campusSetting               object
# medianBaseSalary           float64
# longitude                  float64
# latitude                   float64
# website                     object
# phoneNumber                 object
# city                        object
# country                     object
# state.1                     object
# region                      object
# yearFounded                float64
# stateCode                   object
# collegeType                 object
# carnegieClassification      object
# studentFacultyRatio          int64
# totalStudentPop              int64
# undergradPop                 int64
# totalGrantAid              float64
# percentOfStudentsFinAid    float64
# percentOfStudentsGrant     float64
# dtype: object

# %%
df.describe()
# Out:
#              rank  studentPopulation  medianBaseSalary   longitude  \
# count  498.000000         498.000000        491.000000  458.000000
# mean   249.487952       16073.983936     116382.077393  -88.871596
# std    143.895897       16284.865007      17161.769465   18.490733
# min      1.000000         421.000000      77300.000000 -157.820047
# 25%    125.250000        3112.500000     104300.000000  -96.924510
# 50%    249.500000        9850.000000     112800.000000  -84.251869
# 75%    373.750000       24363.000000     125000.000000  -75.471093
# max    498.000000      102826.000000     173700.000000   85.501600
#
#          latitude  yearFounded  studentFacultyRatio  totalStudentPop  \
# count  458.000000   451.000000           498.000000       498.000000
# mean    39.082492  1879.944568            14.120482     16073.983936
# std      4.481500    50.805940             5.203074     16284.865007
# min     21.299373  1636.000000             3.000000       421.000000
# ...

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName state  studentPopulation  \
# 0  Massachusetts Institute of Technology    MA              12195
#
#   campusSetting  medianBaseSalary  longitude   latitude             website  \
# 0         Urban          173700.0 -71.093539  42.359006  http://web.mit.edu
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#    totalStudentPop undergradPop totalGrantAid percentOfStudentsFinAid  \
# 0            12195         4582    35299332.0                    75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 25 columns]

# %%
df.drop('state',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['description', 'rank', 'organizationName', 'studentPopulation',
#        'campusSetting', 'medianBaseSalary', 'longitude', 'latitude', 'website',
#        'phoneNumber', 'city', 'country', 'state.1', 'region', 'yearFounded',
#        'stateCode', 'collegeType', 'carnegieClassification',
#        'studentFacultyRatio', 'totalStudentPop', 'undergradPop',
#        'totalGrantAid', 'percentOfStudentsFinAid', 'percentOfStudentsGrant'],
#       dtype='object')

# %%
df.rename(columns={'state.1':'state'},inplace=True)

# %%
df.columns
# Out:
# Index(['description', 'rank', 'organizationName', 'studentPopulation',
#        'campusSetting', 'medianBaseSalary', 'longitude', 'latitude', 'website',
#        'phoneNumber', 'city', 'country', 'state', 'region', 'yearFounded',
#        'stateCode', 'collegeType', 'carnegieClassification',
#        'studentFacultyRatio', 'totalStudentPop', 'undergradPop',
#        'totalGrantAid', 'percentOfStudentsFinAid', 'percentOfStudentsGrant'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName  studentPopulation campusSetting  \
# 0  Massachusetts Institute of Technology              12195         Urban
#
#    medianBaseSalary  longitude   latitude             website   phoneNumber  \
# 0          173700.0 -71.093539  42.359006  http://web.mit.edu  617-253-1000
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification  studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                    3
#
#   totalStudentPop undergradPop totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582    35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 24 columns]

# %%
df.drop('studentPopulation',axis=1,inplace=True)
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# description                 0
# rank                        0
# organizationName            0
# campusSetting               0
# medianBaseSalary            7
# longitude                  40
# latitude                   40
# website                    21
# phoneNumber                70
# city                        0
# country                     0
# state                       0
# region                      9
# yearFounded                47
# stateCode                   9
# collegeType                 0
# carnegieClassification      0
# studentFacultyRatio         0
# totalStudentPop             0
# undergradPop                0
# totalGrantAid               3
# percentOfStudentsFinAid     3
# percentOfStudentsGrant      3
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# description                0
# rank                       0
# organizationName           0
# campusSetting              0
# medianBaseSalary           0
# longitude                  0
# latitude                   0
# website                    0
# phoneNumber                0
# city                       0
# country                    0
# state                      0
# region                     0
# yearFounded                0
# stateCode                  0
# collegeType                0
# carnegieClassification     0
# studentFacultyRatio        0
# totalStudentPop            0
# undergradPop               0
# totalGrantAid              0
# percentOfStudentsFinAid    0
# percentOfStudentsGrant     0
# dtype: int64

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
csn=np.array(df.campusSetting.unique())
cs=np.array(df.campusSetting.value_counts())

# %%
# %matplotlib inline
plt.plot(csn,cs,linewidth=5)

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
# %matplotlib inline
ct=np.array(df.collegeType.value_counts())
ctn=np.array(df.collegeType.unique())

# %%
plt.bar(ctn,ct,color={'red','yellow'})
# Out:
# <BarContainer object of 2 artists>

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
df.state.value_counts()
# Out:
# New York                51
# California              45
# Pennsylvania            30
# Texas                   23
# Massachusetts           22
# Ohio                    15
# Illinois                15
# Indiana                 12
# Michigan                11
# Florida                 11
# Virginia                11
# Minnesota               11
# New Jersey              11
# Washington              10
# North Carolina           9
# Oregon                   9
# Missouri                 8
# Georgia                  8
# Maryland                 8
# Tennessee                7
# Connecticut              7
# Wisconsin                6
# Colorado                 6
# South Carolina           6
# Alabama                  5
# Iowa                     5
# District of Columbia     5
# Rhode Island             4
# Louisiana                4
# Kentucky                 4
# Arizona                  4
# Utah                     3
# New Mexico               3
# Idaho                    3
# ...

# %%
df[df.state=='New York ']
# Out:
# Empty DataFrame
# Columns: [description, rank, organizationName, campusSetting, medianBaseSalary, longitude, latitude, website, phoneNumber, city, country, state, region, yearFounded, stateCode, collegeType, carnegieClassification, studentFacultyRatio, totalStudentPop, undergradPop, totalGrantAid, percentOfStudentsFinAid, percentOfStudentsGrant]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
ccn=df.carnegieClassification.unique()
cc=df.carnegieClassification.value_counts()
p=pd.DataFrame(df.carnegieClassification.value_counts())
p
# Out:
#                                                     carnegieClassification
# Doctoral Universities: Very High Research Activity                     121
# Baccalaureate Colleges: Arts & Sciences Focus                          102
# Doctoral Universities: High Research Activity                           76
# Master's Colleges & Universities: Larger Programs                       63
# Doctoral/Professional Universities                                      27
# Master's Colleges & Universities: Medium Programs                       12
# Master's Colleges & Universities: Small Programs                        10
# Baccalaureate Colleges: Diverse Fields                                   7
# Special Focus Four-Year: Engineering Schools                             2
# Special Focus Four-Year: Arts, Music & Design S...                       2

# %%
plt.barh(ccn,cc,color={'red','green','orange','blue','yellow'})
plt.title("TOTAL CARNEGIE CLASSIFICATION")
# Out:
# Text(0.5, 1.0, 'TOTAL CARNEGIE CLASSIFICATION')

# %%
df[df.carnegieClassification.str.contains('Doctoral')]
# Out:
#                                            description  rank  \
# 0    A leading global research university, MIT attr...     1
# 1    Stanford University sits just outside of Palo ...     2
# 2    One of the top public universities in the coun...     3
# 3    Princeton is a leading private research univer...     4
# 4    Located in upper Manhattan, Columbia Universit...     5
# ..                                                 ...   ...
# 483  Southern Illinois University, Edwardsville ope...   484
# 484  Sam Houston State is a large, public research ...   485
# 485  Belmont University in Nashville, TN, is a priv...   486
# 490  Loyola University New Orleans provides student...   491
# 497  The University of Memphis is a large public re...   498
#
#                               organizationName campusSetting  \
# 0        Massachusetts Institute of Technology         Urban
# 1                          Stanford University      Suburban
# ...

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
df1=df[['rank','organizationName','totalStudentPop','state','campusSetting','website','phoneNumber','collegeType','carnegieClassification']]
df1.max()
# Out:
# rank                                                               498
# organizationName                                    Yeshiva University
# totalStudentPop                                                  82880
# state                                                          Wyoming
# campusSetting                                                    Urban
# website                            http://www4.lehigh.edu/default.aspx
# phoneNumber                                               979-845-3211
# collegeType                                                     Public
# carnegieClassification    Special Focus Four-Year: Engineering Schools
# dtype: object

# %%
df1=df[['rank','organizationName','totalStudentPop','state','campusSetting','website','phoneNumber','collegeType','carnegieClassification']]
df1.min()
# Out:
# rank                                                                  1
# organizationName                           Abilene Christian University
# totalStudentPop                                                     425
# state                                                           Alabama
# campusSetting                                                     Rural
# website                                            http://allegheny.edu
# phoneNumber                                              (205) 726-2011
# collegeType                                      Private not-for-profit
# carnegieClassification    Baccalaureate Colleges: Arts & Sciences Focus
# dtype: object

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName campusSetting  medianBaseSalary  \
# 0  Massachusetts Institute of Technology         Urban          173700.0
#
#    longitude   latitude             website   phoneNumber       city  ...  \
# 0 -71.093539  42.359006  http://web.mit.edu  617-253-1000  Cambridge  ...
#
#   yearFounded stateCode             collegeType  \
# 0      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#   totalStudentPop undergradPop  totalGrantAid  percentOfStudentsFinAid  \
# 0           12195         4582     35299332.0                     75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 23 columns]

# %%
r=df[['rank','organizationName','description','website','phoneNumber']]
r[r['rank'] <= 5]
# Out:
#    rank                       organizationName  \
# 0     1  Massachusetts Institute of Technology
# 1     2                    Stanford University
# 2     3     University of California, Berkeley
# 3     4                   Princeton University
# 4     5                    Columbia University
#
#                                          description  \
# 0  A leading global research university, MIT attr...
# 1  Stanford University sits just outside of Palo ...
# 2  One of the top public universities in the coun...
# 3  Princeton is a leading private research univer...
# 4  Located in upper Manhattan, Columbia Universit...
#
#                     website     phoneNumber
# 0        http://web.mit.edu    617-253-1000
# 1   http://www.stanford.edu    650-723-2091
# 2   http://www.berkeley.edu  (510) 642-6000
# 3  http://www.princeton.edu    609-258-3000
# 4   http://www.columbia.edu    212-854-1754
