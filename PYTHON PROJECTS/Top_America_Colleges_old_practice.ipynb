# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("top_america_colleges_2022.csv")
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName state  studentPopulation  \
# 0  Massachusetts Institute of Technology    MA              12195
#
#   campusSetting  medianBaseSalary  longitude   latitude             website  \
# 0         Urban          173700.0 -71.093539  42.359006  http://web.mit.edu
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#    totalStudentPop undergradPop totalGrantAid percentOfStudentsFinAid  \
# 0            12195         4582    35299332.0                    75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 25 columns]

# %%
df.dtypes
# Out:
# description                 object
# rank                         int64
# organizationName            object
# state                       object
# studentPopulation            int64
# campusSetting               object
# medianBaseSalary           float64
# longitude                  float64
# latitude                   float64
# website                     object
# phoneNumber                 object
# city                        object
# country                     object
# state.1                     object
# region                      object
# yearFounded                float64
# stateCode                   object
# collegeType                 object
# carnegieClassification      object
# studentFacultyRatio          int64
# totalStudentPop              int64
# undergradPop                 int64
# totalGrantAid              float64
# percentOfStudentsFinAid    float64
# percentOfStudentsGrant     float64
# dtype: object

# %%
df.shape
# Out:
# (498, 25)

# %%
df.isnull().sum()
# Out:
# description                 0
# rank                        0
# organizationName            0
# state                       0
# studentPopulation           0
# campusSetting               0
# medianBaseSalary            7
# longitude                  40
# latitude                   40
# website                    21
# phoneNumber                70
# city                        0
# country                     0
# state.1                     0
# region                      9
# yearFounded                47
# stateCode                   9
# collegeType                 0
# carnegieClassification      0
# studentFacultyRatio         0
# totalStudentPop             0
# undergradPop                0
# totalGrantAid               3
# percentOfStudentsFinAid     3
# percentOfStudentsGrant      3
# dtype: int64

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# description                0
# rank                       0
# organizationName           0
# state                      0
# studentPopulation          0
# campusSetting              0
# medianBaseSalary           0
# longitude                  0
# latitude                   0
# website                    0
# phoneNumber                0
# city                       0
# country                    0
# state.1                    0
# region                     0
# yearFounded                0
# stateCode                  0
# collegeType                0
# carnegieClassification     0
# studentFacultyRatio        0
# totalStudentPop            0
# undergradPop               0
# totalGrantAid              0
# percentOfStudentsFinAid    0
# percentOfStudentsGrant     0
# dtype: int64

# %%
df.shape
# Out:
# (422, 25)

# %%
df.columns
# Out:
# Index(['description', 'rank', 'organizationName', 'state', 'studentPopulation',
#        'campusSetting', 'medianBaseSalary', 'longitude', 'latitude', 'website',
#        'phoneNumber', 'city', 'country', 'state.1', 'region', 'yearFounded',
#        'stateCode', 'collegeType', 'carnegieClassification',
#        'studentFacultyRatio', 'totalStudentPop', 'undergradPop',
#        'totalGrantAid', 'percentOfStudentsFinAid', 'percentOfStudentsGrant'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName state  studentPopulation  \
# 0  Massachusetts Institute of Technology    MA              12195
#
#   campusSetting  medianBaseSalary  longitude   latitude             website  \
# 0         Urban          173700.0 -71.093539  42.359006  http://web.mit.edu
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#    totalStudentPop undergradPop totalGrantAid percentOfStudentsFinAid  \
# 0            12195         4582    35299332.0                    75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 25 columns]

# %%
all_states=df[['state','state.1']]
all_states
# Out:
#     state        state.1
# 0      MA  Massachusetts
# 1      CA     California
# 2      CA     California
# 3      NJ     New Jersey
# 4      NY       New York
# ..    ...            ...
# 490    LA      Louisiana
# 491    OH           Ohio
# 493    NY       New York
# 494    PA   Pennsylvania
# 497    TN      Tennessee
#
# [422 rows x 2 columns]

# %%
df['state']=df['state']

# %%
df.head()
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
# 1  Stanford University sits just outside of Palo ...     2
# 2  One of the top public universities in the coun...     3
# 3  Princeton is a leading private research univer...     4
# 4  Located in upper Manhattan, Columbia Universit...     5
#
#                         organizationName          state  studentPopulation  \
# 0  Massachusetts Institute of Technology  Massachusetts              12195
# 1                    Stanford University     California              20961
# 2     University of California, Berkeley     California              45878
# 3                   Princeton University     New Jersey               8532
# 4                    Columbia University       New York              33882
#
#   campusSetting  medianBaseSalary   longitude   latitude  \
# 0         Urban          173700.0  -71.093539  42.359006
# ...

# %%
all_states=df[['state','state.1']]
all_states
# Out:
#              state        state.1
# 0    Massachusetts  Massachusetts
# 1       California     California
# 2       California     California
# 3       New Jersey     New Jersey
# 4         New York       New York
# ..             ...            ...
# 490      Louisiana      Louisiana
# 491           Ohio           Ohio
# 493       New York       New York
# 494   Pennsylvania   Pennsylvania
# 497      Tennessee      Tennessee
#
# [422 rows x 2 columns]

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName          state  studentPopulation  \
# 0  Massachusetts Institute of Technology  Massachusetts              12195
#
#   campusSetting  medianBaseSalary  longitude   latitude             website  \
# 0         Urban          173700.0 -71.093539  42.359006  http://web.mit.edu
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#    totalStudentPop undergradPop totalGrantAid percentOfStudentsFinAid  \
# 0            12195         4582    35299332.0                    75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 25 columns]

# %%
df.groupby('state')['organizationName'].count().sort_values(ascending=False)
# Out:
# state
# New York                51
# California              45
# Pennsylvania            30
# Texas                   23
# Massachusetts           22
# Ohio                    15
# Illinois                15
# Indiana                 12
# Virginia                11
# Minnesota               11
# Florida                 11
# New Jersey              11
# Michigan                11
# Washington              10
# North Carolina           9
# Oregon                   9
# Missouri                 8
# Maryland                 8
# Georgia                  8
# Tennessee                7
# Connecticut              7
# Wisconsin                6
# South Carolina           6
# Colorado                 6
# Alabama                  5
# District of Columbia     5
# Iowa                     5
# Louisiana                4
# Kentucky                 4
# Arizona                  4
# Rhode Island             4
# Maine                    3
# New Mexico               3
# Idaho                    3
# ...

# %%
df[df.state=='New York']
# Out:
#                                            description  rank  \
# 4    Located in upper Manhattan, Columbia Universit...     5
# 15   Set on a hill overlooking Ithaca, NY, Cornell ...    16
# 43   Colgate University is a leading liberal arts s...    44
# 52   Hamilton College, a small private school in Cl...    53
# 59   New York University is a large private researc...    60
# 64   Founded in 1946 to educate World War II vetera...    65
# 65   Baruch College, part of the City University of...    66
# 70   A prestigious women’s college in New York City...    71
# 72   A premier liberal arts school in Poughkeepsie,...    73
# 85   A member of the State University of New York s...    86
# 89   The largest public research institution in the...    90
# 96   The University of Rochester is a midsize priva...    97
# 101  Syracuse is a private research university in t...   102
# 121  Located in the picturesque college town of Sar...   122
# ...

# %%
ct=df.collegeType.value_counts()
ct
# Out:
# Private not-for-profit    237
# Public                    185
# Name: collegeType, dtype: int64

# %%
p=np.array(ct)
mylabels = ["Private Non For Profit = 237", "Public = 185"]
plt.pie(p,labels=mylabels)
plt.show()

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName state  studentPopulation  \
# 0  Massachusetts Institute of Technology    MA              12195
#
#   campusSetting  medianBaseSalary  longitude   latitude             website  \
# 0         Urban          173700.0 -71.093539  42.359006  http://web.mit.edu
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#    totalStudentPop undergradPop totalGrantAid percentOfStudentsFinAid  \
# 0            12195         4582    35299332.0                    75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 25 columns]

# %%
df_pop=df[['organizationName','state','studentPopulation']]
df_pop.max()
# Out:
# organizationName     Yeshiva University
# state                                WY
# studentPopulation                102826
# dtype: object

# %%
df_pop=df[['organizationName','state','studentPopulation','campusSetting']]
df_pop[(df_pop['campusSetting']=='Urban')&(df_pop['studentPopulation']>10000)]
# Out:
#                              organizationName state  studentPopulation  \
# 0       Massachusetts Institute of Technology    MA              12195
# 2          University of California, Berkeley    CA              45878
# 4                         Columbia University    NY              33882
# 5       University of California, Los Angeles    CA              46947
# 7                             Yale University    CT              14910
# ..                                        ...   ...                ...
# 471                   Old Dominion University    VA              28042
# 478   University of Colorado Colorado Springs    CO              16715
# 480               University of Northern Iowa    IA              12137
# 481  University of North Carolina, Greensboro    NC              22487
# 497                     University of Memphis    TN              25128
#
#     campusSetting
# 0           Urban
# 2           Urban
# 4           Urban
# 5           Urban
# ...

# %%
df.head(1)
# Out:
#                                          description  rank  \
# 0  A leading global research university, MIT attr...     1
#
#                         organizationName state  studentPopulation  \
# 0  Massachusetts Institute of Technology    MA              12195
#
#   campusSetting  medianBaseSalary  longitude   latitude             website  \
# 0         Urban          173700.0 -71.093539  42.359006  http://web.mit.edu
#
#    ... yearFounded stateCode             collegeType  \
# 0  ...      1861.0        MA  Private not-for-profit
#
#                               carnegieClassification studentFacultyRatio  \
# 0  Doctoral Universities: Very High Research Acti...                   3
#
#    totalStudentPop undergradPop totalGrantAid percentOfStudentsFinAid  \
# 0            12195         4582    35299332.0                    75.0
#
#    percentOfStudentsGrant
# 0                    60.0
#
# [1 rows x 25 columns]

# %%
df['campusSetting'].value_counts()
# Out:
# Urban       292
# Suburban    130
# Rural        76
# Name: campusSetting, dtype: int64

# %%
df['campusSetting'].value_counts().plot(kind='barh',color=['blue','green','yellow'])
# Out:
# <AxesSubplot:>
