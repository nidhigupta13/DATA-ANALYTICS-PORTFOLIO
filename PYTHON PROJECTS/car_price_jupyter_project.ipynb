# %% [markdown]
# # CAR PRICE DATASET ANALYSIS

# %%
import pandas as pd
import matplotlib as plt

df=pd.read_csv('car_price.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2           2                      Toyota Camry 2.5 G          16.40 Lakh
# 3           3                       Honda Jazz VX CVT           7.77 Lakh
# 4           4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %% [markdown]
# # TOTAL NO. OF ROWS AND COLUMNS

# %%
df.shape
# Out:
# (5512, 10)

# %%
df.describe()
# Out:
#         Unnamed: 0  manufacture
# count  5512.000000  5512.000000
# mean   2755.500000  2015.455552
# std    1591.321673     3.927974
# min       0.000000  1995.000000
# 25%    1377.750000  2013.000000
# 50%    2755.500000  2016.000000
# 75%    4133.250000  2018.000000
# max    5511.000000  2022.000000

# %%
df.head()
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2           2                      Toyota Camry 2.5 G          16.40 Lakh
# 3           3                       Honda Jazz VX CVT           7.77 Lakh
# 4           4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %% [markdown]
# # RENAME COLUMN 1 "UNNAMED" AS ID

# %%
df.rename(columns = {'Unnamed: 0':'ID'}, inplace = True)

# %%
df.head()
# Out:
#    ID                                car_name car_prices_in_rupee  kms_driven  \
# 0   0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1   1            Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2   2                      Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3   3                       Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4   4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
#
#   fuel_type transmission  ownership  manufacture   engine    Seats
# 0    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %% [markdown]
# # COUNT THE TOTAL NO OF CARS OF EACH FUEL TYPE

# %%
f=df['fuel_type'].value_counts()
f
# Out:
# Petrol      2967
# Diesel      2423
# Cng           80
# Lpg           28
# Electric      14
# Name: fuel_type, dtype: int64

# %%
f.plot(kind="barh",color="blue")
# Out:
# <AxesSubplot:>

# %%
df.head(2)
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats

# %% [markdown]
# # TOTAL NO OF RECORDS WHICH HAS CAR PRICE GREATER THAN 5 LAKH

# %%
p=(df['car_prices_in_rupee'] > "5 lakh").value_counts()
p
# Out:
# False    3646
# True     1866
# Name: car_prices_in_rupee, dtype: int64

# %%
p.plot(kind="bar",color={'red','green'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ALL RECORDS WHICH HAS CAR PRICE GREATER THAN 5 LAKH

# %%
df[df['car_prices_in_rupee'] > "5 lakh"]
# Out:
#       Unnamed: 0                                   car_name  \
# 3              3                          Honda Jazz VX CVT
# 4              4           Volkswagen Polo 1.2 MPI Highline
# 5              5       Volkswagen Vento 1.2 TSI Highline AT
# 6              6  Volkswagen Vento 1.2 TSI Highline Plus AT
# 8              8                   Honda City i VTEC CVT SV
# ...          ...                                        ...
# 5490        5490                      Mercedes-Benz GLC 200
# 5497        5497               Volvo XC 90 D5 Momentum BSIV
# 5501        5501               Hyundai i20 Sportz Plus BSIV
# 5505        5505              Maruti Vitara Brezza ZDi Plus
# 5508        5508                      BMW M Series M4 Coupe
#
#      car_prices_in_rupee  kms_driven fuel_type transmission  ownership  \
# 3              7.77 Lakh  26,696 kms    Petrol    Automatic  1st Owner
# 4              5.15 Lakh  69,414 kms    Petrol       Manual  1st Owner
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats

# %% [markdown]
# # TOTAL NO OF RECORDS WHICH HAS CAR PRICE GREATER THAN 10 LAKH

# %%
q=(df['car_prices_in_rupee'] > "10 lakh").value_counts()
q
# Out:
# True     4921
# False     591
# Name: car_prices_in_rupee, dtype: int64

# %%
df[df['car_prices_in_rupee'] > "10 lakh"]
# Out:
#       Unnamed: 0                                car_name car_prices_in_rupee  \
# 0              0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1              1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2              2                      Toyota Camry 2.5 G          16.40 Lakh
# 3              3                       Honda Jazz VX CVT           7.77 Lakh
# 4              4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
# ...          ...                                     ...                 ...
# 5507        5507                 BMW X1 sDrive 20d xLine          28.90 Lakh
# 5508        5508                   BMW M Series M4 Coupe          64.90 Lakh
# 5509        5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh
# 5510        5510                      BMW 7 Series 730Ld          29.90 Lakh
# 5511        5511               BMW 5 Series 520d M Sport          31.90 Lakh
#
# ...

# %%
q.plot(kind="bar",color={'grey','brown'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # TOTAL NO OF RECORDS FOR EACH TYPE OF TRANSMISSION

# %%
df.head(2)
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats

# %%
df['transmission'].value_counts()
# Out:
# Manual       3962
# Automatic    1550
# Name: transmission, dtype: int64

# %%
df['transmission'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='transmission'>

# %% [markdown]
# # TOTAL NO OF RECORDS UNDER EACH TYPE OF OWNERSHIP

# %%
o=df['ownership'].value_counts()
o
# Out:
# 1st Owner    3736
# 2nd Owner    1314
# 3rd Owner     359
# 4th Owner      84
# 5th Owner      12
# 0th Owner       7
# Name: ownership, dtype: int64

# %%
o.plot(kind="bar",color={'red','blue','green','yellow','orange','black'})
# Out:
# <AxesSubplot:>

# %%
df.head(2)
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats

# %% [markdown]
# #  SHOW THE RECORDS IN "SEAT" COLUMN OF "2 SEATS" AND "5 SEATS"

# %%
df.groupby('Seats').get_group("2 Seats")
# Out:
#       Unnamed: 0                                  car_name  \
# 853          853             Jaguar XF 2.0 Petrol Prestige
# 938          938                    Maruti Swift Dzire VXI
# 2115        2115                      Maruti SX4 Vxi BSIII
# 3369        3369  Volkswagen Ameo 1.5 TDI Highline Plus 16
# 4103        4103                          Renault KWID RXL
#
#      car_prices_in_rupee    kms_driven fuel_type transmission  ownership  \
# 853              47 Lakh     7,500 kms    Petrol    Automatic  1st Owner
# 938            7.20 Lakh     6,200 kms    Petrol       Manual  1st Owner
# 2115           1.70 Lakh  1,20,000 kms    Petrol       Manual  2nd Owner
# 3369           5.35 Lakh    50,000 kms    Diesel       Manual  2nd Owner
# 4103           2.70 Lakh    20,000 kms    Petrol       Manual  2nd Owner
#
#       manufacture   engine    Seats
# 853          2020  2494 cc  2 Seats
# 938          2022  1998 cc  2 Seats
# 2115         2007  1798 cc  2 Seats
# ...

# %%
df.groupby('Seats').get_group("5 Seats")
# Out:
#       Unnamed: 0                                car_name car_prices_in_rupee  \
# 0              0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1              1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2              2                      Toyota Camry 2.5 G          16.40 Lakh
# 3              3                       Honda Jazz VX CVT           7.77 Lakh
# 4              4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
# ...          ...                                     ...                 ...
# 5502        5502         Mercedes-Benz CLA 200 CDI Sport          23.90 Lakh
# 5506        5506                       BMW X5 xDrive 30d          32.90 Lakh
# 5508        5508                   BMW M Series M4 Coupe          64.90 Lakh
# 5509        5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh
# 5511        5511               BMW 5 Series 520d M Sport          31.90 Lakh
#
# ...

# %% [markdown]
# # NO OF DIFFERENT TYPES ENGINES

# %%
df['engine'].value_counts()
# Out:
# 1197 cc    714
# 1248 cc    395
# 998 cc     346
# 1498 cc    252
# 1497 cc    245
#           ...
# 1173 cc      1
# 2359 cc      1
# 5950 cc      1
# 3956 cc      1
# 2979 cc      1
# Name: engine, Length: 139, dtype: int64

# %%
df['engine'].value_counts().plot(kind="hist",color="violet")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # SHOW THE RECORDS WHERE "ENGINE" IS "1956 CC"

# %%
df.groupby('engine').get_group("1956 cc")
# Out:
#       Unnamed: 0                                  car_name  \
# 0              0    Jeep Compass 2.0 Longitude Option BSIV
# 23            23        Jeep Compass 2.0 Limited Plus BSIV
# 42            42                  Jeep Compass 2.0 Limited
# 44            44                      Tata Harrier XZ BSIV
# 87            87     MG Hector Plus Select Diesel MT 7 STR
# ...          ...                                       ...
# 5251        5251  Land Rover Range Rover Vogue SE 4.4 SDV8
# 5252        5252                    BMW X1 sDrive20i xLine
# 5298        5298           Mercedes-Benz S-Class S 350 CDI
# 5385        5385                      Nissan Magnite XV DT
# 5461        5461      Audi Q3 2.0 TDI Quattro Premium Plus
#
#      car_prices_in_rupee  kms_driven fuel_type transmission  ownership  \
# 0             10.03 Lakh  86,226 kms    Diesel       Manual  1st Owner
# 23            15.88 Lakh  15,414 kms    Diesel       Manual  1st Owner
# ...

# %%
x=df[df["kms_driven"]>"50,000 kms"].count().sum()
x
# Out:
# 24040

# %%
y=df[df["kms_driven"]<"10,000 kms"].count().sum()
y
# Out:
# 8340
